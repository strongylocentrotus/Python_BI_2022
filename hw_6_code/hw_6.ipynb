# %% [markdown]
# <a href="https://colab.research.google.com/github/strongylocentrotus/Python_BI_2022/blob/sixth/hw_6_code/hw_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import matplotlib.pyplot as plt

# %%
path = '/content/references.txt'

with open(f'{path}') as references:
    references = references.read()
    ftp_sep = re.sub(r';', ' ', references)
    ftps = re.findall(r'ftp[\w./]+', ftp_sep)

with open(r'/content/ftps.txt', 'w') as ftps_sheet:
    ftps_sheet.write('\n'.join(str(ftp) for ftp in ftps))

# %%
def number_getter(file):
    return re.findall('[0-9]+.[0-9]+', file)

def a_getter(file):
    return re.findall(r'\w*a+\w*', file, flags=re.IGNORECASE)
  
def excl_getter(file):
    return re.findall(r'[\w,\s]+!', file)

def uniq_getter(file):
    all_words = re.findall(r'[a-zA-z\'\-]+', novel)
    return list(set(map(lambda x: x.lower(), all_words)))

# %%
path_2 = '2430AD.txt'
with open(f'{path_2}') as novel:
    novel = novel.read()
    novel_num = number_getter(novel)
    novel_a_words = a_getter(novel)
    exclam_sent = excl_getter(novel)
    unique_words = uniq_getter(novel)

# %%
 unique_words
# Out:
# ['office',
#  'one',
#  'activities',
#  'sleep',
#  'wall',
#  'war',
#  'character',
#  'whispered',
#  'sector',
#  'fusion',
#  'published',
#  'feared',
#  '-j',
#  'births',
#  'substance',
#  'door',
#  'dawn',
#  'living',
#  'indeed',
#  'only',
#  'departed',
#  'came',
#  'trillions',
#  'choked',
#  'crosscorridors',
#  'rebelliously',
#  'around',
#  'told',
#  'b',
#  'made',
#  'might',
#  'because',
#  'evolution',
#  'vapors',
#  'worked',
#  'rabbits',
#  'being',
#  'friend',
#  'been',
#  "couldn't",
#  'worlds',
#  'them-the',
#  'tiny',
#  'square',
#  'blank',
#  "it's",
#  'complex',
#  '-have',
#  'softer',
#  "wouldn't",
#  'going',
#  'need',
#  'kind',
#  'get',
#  'gathered',
#  'sunlamps',
#  'thousands',
#  'or',
#  'gleam',
#  'empty',
#  'does',
#  'creatures',
#  'them',
#  'surprise',
#  "father's",
#  'carnivores',
#  'found',
#  'consume',
#  'honored',
#  'lifted',
#  'explosion',
#  'irradiated',
#  'generation',
#  'someday',
#  'necessarily',
#  'plastic-knit',
#  'filled',
#  'middle',
#  'should',
#  'life',
#  'years',
#  'restore',
#  'forever',
#  'vehicles',
#  'genetic',
#  'there',
#  "we've",
#  'different',
#  'swung',
#  'irritates',
#  'paid',
#  'back',
#  'inside',
#  'behind',
#  'dinosaurs',
#  'room',
#  'seventy-five',
#  'endless',
#  'birth',
#  'from',
#  'yourself',
#  'larger',
#  'evaluate',
#  'crowded-and',
#  'colony',
#  'have',
#  'look',
#  'single',
#  'bought',
#  'come',
#  'than',
#  'whether',
#  'twenty-one',
#  'lips',
#  'earth',
#  'each',
#  'like',
#  'that',
#  'reached',
#  'gone',
#  'knee',
#  'nor',
#  'favor',
#  'whole',
#  'pale',
#  'difference',
#  'land',
#  'just',
#  'my',
#  'person',
#  'begin',
#  'sounded',
#  'few',
#  'care',
#  'rid',
#  'ad',
#  'blood',
#  'direction',
#  'reason',
#  'goal',
#  'waited',
#  'sigh',
#  'uninhabited',
#  'moving',
#  'fifty',
#  'species',
#  'yield',
#  'brain',
#  'dropped',
#  'amused',
#  'colonize',
#  'turn',
#  'motives-and',
#  'almost',
#  'having',
#  'doing',
#  'nightmare',
#  'two',
#  'keep',
#  'say',
#  'ignorant',
#  'crime',
#  'blade',
#  'months',
#  'sink',
#  'already',
#  'recognize',
#  'representative',
#  'so',
#  'another',
#  'correspondingly',
#  "we'll",
#  'twentieth-century',
#  "let's",
#  'brought',
#  'norm',
#  'placidly',
#  'ask',
#  'ache',
#  'pump',
#  'deaths',
#  'regulated',
#  'trying',
#  'wiped',
#  "hadn't",
#  'books',
#  'solar',
#  'harvest',
#  'neither',
#  'lizards',
#  'fears',
#  'planet',
#  'thinking',
#  'hero',
#  'peaceful',
#  'they',
#  'ago',
#  'replaced',
#  'celebrate',
#  'stare',
#  'wants',
#  'striving',
#  'long',
#  'carefully',
#  'imitating',
#  'wastes',
#  'down',
#  'billions',
#  'animal',
#  'mighty',
#  'live',
#  'hundred',
#  'beings-',
#  'jackass',
#  'talking',
#  "you're",
#  'variety',
#  "they'll",
#  'remind',
#  'multiplication',
#  'right',
#  'escape',
#  'art',
#  'cannot',
#  'building',
#  'underfoot',
#  'machinery',
#  'below',
#  'wasteful',
#  'hum',
#  'plankton',
#  'unsettling',
#  'pressure',
#  'confined',
#  'doomed',
#  'what',
#  'tons',
#  'either',
#  'tall',
#  'cranwitz',
#  'long-standing',
#  'irritably',
#  'york',
#  'stubbornly',
#  'treated',
#  'right-',
#  'organic',
#  'eyes',
#  'off',
#  'rumpled',
#  'placid',
#  'note',
#  'crept',
#  'dredges',
#  'leading',
#  'withhold',
#  'universal',
#  'numbered',
#  'himself',
#  'tolerated',
#  'along',
#  'added',
#  'finally',
#  'zoo',
#  'normal',
#  'also',
#  "don't",
#  'sympathy',
#  'establishment',
#  'capable',
#  'govern',
#  'a',
#  'scientific',
#  'day',
#  'fulfilled',
#  'libraries',
#  'centuries',
#  'carry',
#  'margin',
#  'symmetry',
#  'light-years',
#  'time',
#  'thoughts',
#  'enter',
#  'necessary',
#  'flesh',
#  'conveyors',
#  'matter',
#  'largest',
#  'far',
#  'weight',
#  'clear',
#  'most',
#  "that's",
#  'disconcerting',
#  'understand',
#  'energy',
#  'plentiful',
#  'sunlight',
#  'heaved',
#  'resistance',
#  'madness',
#  'quantity',
#  'tens',
#  'priestly',
#  "didn't",
#  'pool',
#  'unusual',
#  'touched',
#  'contract',
#  'peace',
#  'million',
#  'asking',
#  'editor',
#  'case',
#  'grisly',
#  'us',
#  'snorted',
#  'hours',
#  'about',
#  'nothingness',
#  'entirely',
#  "'good",
#  'beside',
#  'muscular',
#  'census-',
#  'persuade',
#  'sun',
#  'circling',
#  'grass',
#  'read',
#  'distinction',
#  'infinite',
#  'many',
#  'against',
#  'over',
#  'neurotic',
#  'crossing',
#  'i',
#  'earthlike',
#  'become',
#  'forethought',
#  'brightened',
#  'not',
#  'little',
#  'placidity',
#  'even',
#  'lightly',
#  'anywhere',
#  'd',
#  'instance',
#  'heightened',
#  'alvarez',
#  'our',
#  'remained',
#  'starship',
#  'its',
#  'build',
#  'voice',
#  'eventually',
#  'but',
#  'uniformity',
#  'strips',
#  'as',
#  'choice',
#  'involved',
#  'campbell',
#  'insist',
#  'dreamed',
#  'role',
#  'insinuating',
#  'grew',
#  'small',
#  'escaped',
#  'rather',
#  'walking',
#  'multiply',
#  'handing',
#  'situation',
#  'wounds',
#  'perfection',
#  'stronger',
#  'flaw',
#  'will',
#  'standing',
#  'total',
#  'adjusted',
#  'close',
#  'idea',
#  'while',
#  'throat',
#  'hope',
#  'could',
#  'let',
#  'of',
#  'asked',
#  'harm',
#  'worry',
#  'done',
#  'advance',
#  'infants',
#  'start',
#  'matches',
#  'thinking-why',
#  'side',
#  'it',
#  'bunting',
#  'ones',
#  'opened',
#  'mankind',
#  'ashamed',
#  'mammals',
#  'unallayed',
#  'agree',
#  'john',
#  'trail',
#  'population',
#  'food',
#  'must',
#  'future',
#  'mad',
#  'ibm',
#  'taking',
#  'by',
#  'gaze',
#  'worried',
#  'spent',
#  'amphibians',
#  'rejected',
#  'ten',
#  'on',
#  'peak',
#  'bloc',
#  'now',
#  'moon',
#  'idealist-can',
#  'tell',
#  'greatest',
#  'tortoise',
#  'year',
#  'ecology',
#  'stars',
#  'cages',
#  'apartment',
#  'audible',
#  'calories',
#  'animals',
#  'continental',
#  'executive',
#  'unbroken',
#  'question',
#  'system',
#  'century',
#  'word',
#  'slow',
#  'amount',
#  'replacement',
#  'feed',
#  'giant',
#  'abandoned',
#  'conduit',
#  'all',
#  'to',
#  'courtesy',
#  'heat',
#  'scorn',
#  'twenty',
#  'varied',
#  'fun',
#  'more',
#  '-but',
#  'through',
#  'into',
#  'economy',
#  'humanity',
#  "i'll",
#  "we're",
#  'achieved',
#  'cells',
#  'maintained',
#  'waiting',
#  'known',
#  'always',
#  'under',
#  'family',
#  'same',
#  "doesn't",
#  'whom',
#  'him',
#  'men',
#  'own',
#  'unable',
#  'tested',
#  'stepped',
#  'cold',
#  'together',
#  'see',
#  'process',
#  'slightly',
#  'settle',
#  'tone',
#  'signaled',
#  'carbon',
#  'when',
#  'broke',
#  'hand',
#  'smell',
#  'conceivable',
#  'pig',
#  'fiction',
#  'air',
#  'stairs',
#  'passed',
#  'ran',
#  'may',
#  'exactly',
#  'plants',
#  'heard',
#  'immersing',
#  'utterly',
#  'wasted',
#  'appropriate',
#  'distortions',
#  'inhabitants',
#  'everyone',
#  'such',
#  'basked',
#  'over-romanticized',
#  'fit',
#  "he'll",
#  'kinds',
#  'present',
#  'sullen',
#  'gray',
#  'has',
#  'trees',
#  'paused',
#  'genius',
#  'home',
#  'took',
#  'extent',
#  'farms',
#  'rich',
#  'man',
#  'conviction',
#  'guinea',
#  'adjustment',
#  'growth',
#  'trillion',
#  'simple',
#  "bunting's",
#  'represent',
#  'acted',
#  'millennia',
#  'exquisite',
#  'comes',
#  'story',
#  'studied',
#  'called',
#  'microfilms',
#  'which',
#  'persuaded',
#  'toleosts',
#  'deep',
#  'development',
#  'easy',
#  'here',
#  'worthwhile',
#  'saw',
#  'last',
#  'gently',
#  'annoyance',
#  'above',
#  'was',
#  'disregarded',
#  'changed',
#  'color',
#  'words',
#  'accepted',
#  'whose',
#  'instinct',
#  'credit',
#  'except',
#  'at',
#  'fan',
#  'killed',
#  'first',
#  'fixed',
#  'crazy',
#  'two-room',
#  'occupied',
#  'were',
#  'refuse',
#  'force',
#  'rate',
#  'supported',
#  'more-till',
#  'much',
#  'great',
#  'quirked',
#  'some',
#  'the',
#  'organized',
#  'knew',
#  'bit',
#  'generously',
#  'shrugged',
#  'combination',
#  "other's",
#  'buildings',
#  'real',
#  'spoke',
#  'written',
#  'we',
#  'government',
#  'tact',
#  'history',
#  'seemed',
#  'numbers',
#  'thin',
#  'computers',
#  'yes',
#  'universe',
#  'enlightened',
#  'survive',
#  'how',
#  'forms',
#  'compare',
#  'exasperation',
#  'reptiles',
#  'sat',
#  'placoderms',
#  'rampways',
#  'packed',
#  'prohibitive',
#  'goes',
#  'planetary',
#  'dolefully',
#  'well',
#  'vision',
#  'me',
#  'felt',
#  'quivered',
#  'dry',
#  'stroked',
#  "alvarez's",
#  'construction',
#  'journey',
#  'dioxide',
#  'every',
#  'newton',
#  'odor',
#  'trilobites',
#  'fifteen',
#  'when-',
#  'are',
#  'go',
#  'bound',
#  'attempt',
#  'softly',
#  'used',
#  'sickening',
#  'thought',
#  'quietly',
#  'good',
#  'residue',
#  'things',
#  'learn',
#  'corner',
#  'wore',
#  'really',
#  'rooms',
#  'he',
#  'though',
#  'new',
#  'light',
#  'not-quite-perfection',
#  "wasn't",
#  'hair',
#  'moved',
#  'destination',
#  'rounder',
#  'eye',
#  'longer',
#  'soil',
#  'repaired',
#  'shifting',
#  'considered',
#  'act',
#  'lived',
#  'your',
#  "haven't",
#  'equal',
#  'succeed',
#  'write',
#  'seven-hundred-level',
#  'looked',
#  'learning',
#  'up',
#  'routinely',
#  'somehow',
#  'you',
#  'way',
#  'something',
#  'estimated',
#  'reach',
#  'exploited',
#  'want',
#  'do',
#  'conduits',
#  'can',
#  'perhaps',
#  'foolish',
#  'stood',
#  'disturb',
#  'hostile',
#  'nothing',
#  'power',
#  'hundreds',
#  'footsteps',
#  'ocean',
#  'expect',
#  'ready',
#  'myself',
#  'clothes',
#  'human',
#  'doubles',
#  'head',
#  'and',
#  'miles',
#  'jaw',
#  'vice-representative',
#  'death',
#  'shook',
#  'enjoy',
#  'five',
#  'established',
#  'soup',
#  'uncomprehending',
#  'who',
#  'divided',
#  'why',
#  'midnight',
#  'tended',
#  'quite',
#  'everything',
#  'never',
#  'thing',
#  'forget',
#  'half',
#  'varieties',
#  'people',
#  'would',
#  'without',
#  'dryly',
#  'events',
#  'minutes',
#  'large',
#  'counted',
#  'crowned',
#  'computer',
#  'talk',
#  'space',
#  'an',
#  'period',
#  'manner',
#  'pigs',
#  'his',
#  'supporting',
#  'end',
#  'fed',
#  'old',
#  'fingers',
#  'silence',
#  'millions',
#  'briefly',
#  'after',
#  'crushed',
#  'measure',
#  'said',
#  'calm',
#  'those',
#  'sparsely',
#  'left',
#  'then',
#  'science',
#  'support',
#  'cheeks',
#  'billion',
#  'wait',
#  'steady',
#  'birds',
#  "shouldn't",
#  'angrily',
#  'personality',
#  'scooped',
#  'preparations',
#  'dreaded',
#  'chance',
#  'increase',
#  'slept',
#  'mice',
#  "cranwitz's",
#  'very',
#  'globe',
#  'if',
#  'uneasily',
#  'had',
#  'soon',
#  'crowds',
#  "won't",
#  "what's",
#  'hold',
#  'woke',
#  "needn't",
#  'twenty-five-even',
#  'meant',
#  'comply',
#  'dwelling',
#  'ground',
#  'past',
#  'corridor',
#  'certain',
#  'fugitive',
#  'descriptions',
#  'chances',
#  'transferred',
#  'take',
#  'in',
#  'city',
#  'open',
#  'these',
#  'muttered',
#  'world',
#  'beings',
#  'feet',
#  'using',
#  'closed',
#  "they're",
#  'stand',
#  'course',
#  'confuse',
#  'experiment',
#  'flooded',
#  'once',
#  'state',
#  'this',
#  'talked',
#  'their',
#  'with',
#  'smelled',
#  'needed',
#  'face',
#  'mind',
#  'bloodshot',
#  'registered',
#  'reaching',
#  'still',
#  'whatever',
#  'corpses',
#  'vast',
#  'edge',
#  'short',
#  'feverishness',
#  'microfilm',
#  'pressure-',
#  'peacefully',
#  'set',
#  'win',
#  'prepared',
#  'endlessly',
#  'figure',
#  'poisoned',
#  'impossible',
#  'did',
#  'seared',
#  'think',
#  'green',
#  'humans-and',
#  'computerized',
#  'life-',
#  'taken',
#  'accede',
#  'other',
#  'advances',
#  'kept',
#  'whiff',
#  'prolific',
#  'muted',
#  'ate',
#  'enjoyed',
#  'killing',
#  "i've",
#  'dried',
#  'decades',
#  'before',
#  'sea',
#  'engineering',
#  'magazine',
#  'inhuman',
#  'avoided',
#  'out',
#  'genetically',
#  'original',
#  'effort',
#  'went',
#  'pure',
#  'then-i',
#  'literally',
#  'faded',
#  "there's",
#  'be',
#  'demanded',
#  'between',
#  'intangible',
#  'sure',
#  'else',
#  'deviants-from-norm',
#  'again',
#  'shall',
#  'rock',
#  'level',
#  'bears',
#  'twenty-five',
#  'fellows',
#  'too',
#  'love',
#  'not-quite-life',
#  'humans',
#  'often',
#  'pounds',
#  'voluntarily',
#  'routine',
#  'itself',
#  'conditions',
#  'odd',
#  'athletic',
#  'cherished',
#  'necessity',
#  'enough',
#  'social',
#  'is',
#  'know',
#  'stayed',
#  'asset',
#  'for',
#  'distance',
#  'show',
#  'capacity',
#  'waved',
#  'no']

# %%
length = list(map(lambda word: len(word), unique_words))

len_number = dict((i, length.count(i)) for i in length)

lengths = list(len_number.keys())

word_number = list(len_number.values())





portion = []
for value in word_number:
    portion.append(value/sum(len_number.values()))
plt.style.use('seaborn-paper')
plt.bar(list(map(str, sorted(lengths))), portion, color='cyan')
plt.xlabel('length', fontsize=12)
plt.ylabel('number', fontsize=12)
# Out:
# Text(0, 0.5, 'number')

# %%
def translate(transwords: str) -> str:
    vowels = 'ауоыэяюёие'
    transwords = re.sub(fr'([{vowels}])', fr'\1к\1', transwords)
    return transwords
